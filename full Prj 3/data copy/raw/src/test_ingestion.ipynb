# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
import src.ingestion as ing

print(dir(ing))
from src.ingestion import ingest_files
df = ingest_files(
    file_paths=[
        'data/raw/clean_data.csv',
        'data/raw/messy_dates.csv',
        'data/raw/missing_fields.csv',
        'data/raw/inconsistent_categories.csv',
        'data/raw/multi_schema.xlsx'
    ],
    config_path='config/schema_map.yaml'
)

print(f"Shape: {df.shape}")
print(f"Columns: {df.columns.tolist()}")
print(f"Unique sources: {df['source_file'].unique()}")
print(f"Null counts:\n{df.isnull().sum()}")
print(f"Row ID range: {df['row_id'].min()} to {df['row_id'].max()}")
print(df.head(5))
# Out:
# ['REQUIRED_COLUMNS', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'add_metadata', 'build_alias_lookup', 'ensure_required_columns', 'ingest_files', 'load_config', 'os', 'pd', 'standardize_columns', 'yaml']
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 5
#       3 print(dir(ing))
#       4 from src.ingestion import ingest_files
# ----> 5 df = ingest_files(
#       6     file_paths=[
#       7         'data/raw/clean_data.csv',
#       8         'data/raw/messy_dates.csv',
#       9         'data/raw/missing_fields.csv',
#      10         'data/raw/inconsistent_categories.csv',
#      11         'data/raw/multi_schema.xlsx'
#      12     ],
#      13     config_path='config/schema_map.yaml'
#      14 )
#      16 print(f"Shape: {df.shape}")
#      17 print(f"Columns: {df.columns.tolist()}")
#
# File ~/Documents/Phase2_projects/Prj_3_freelance_1/src/ingestion.py:38, in ingest_files(file_paths, config_path)
#      37 def ingest_files(file_paths, config_path):
# ---> 38     config = load_config(config_path)
#      39     alias_lookup = build_alias_lookup(config["column_aliases"])
#      41     all_dfs = []
#
# File ~/Documents/Phase2_projects/Prj_3_freelance_1/src/ingestion.py:6, in load_config(config_path)
#       5 def load_config(config_path):
# ----> 6     with open(config_path, "r") as f:
#       7         return yaml.safe_load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'config/schema_map.yaml'
